# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample dataset
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# (a) Data Preprocessing
def preprocess_data(data):
    # Split English and French sentences
    eng_texts = [pair[0] for pair in data]
    fra_texts = ['<start> ' + pair[1] + ' <end>' for pair in data]

    # Create tokenizers
    eng_tokenizer = Tokenizer()
    fra_tokenizer = Tokenizer()

    # Fit tokenizers
    eng_tokenizer.fit_on_texts(eng_texts)
    fra_tokenizer.fit_on_texts(fra_texts)

    # Convert texts to sequences
    eng_sequences = eng_tokenizer.texts_to_sequences(eng_texts)
    fra_sequences = fra_tokenizer.texts_to_sequences(fra_texts)

    # Find maximum lengths
    max_eng_len = max(len(seq) for seq in eng_sequences)
    max_fra_len = max(len(seq) for seq in fra_sequences)

    # Pad sequences
    eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
    fra_padded = pad_sequences(fra_sequences, maxlen=max_fra_len, padding='post')

    return eng_padded, fra_padded, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len

# Process the data
eng_data, fra_data, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len = preprocess_data(data)

# Get vocabulary sizes
eng_vocab_size = len(eng_tokenizer.word_index) + 1
fra_vocab_size = len(fra_tokenizer.word_index) + 1

# Print shapes for debugging
print("Input shapes:")
print(f"English data shape: {eng_data.shape}")
print(f"French data shape: {fra_data.shape}")

# (b) Build Seq2Seq Model
def build_model(input_vocab, output_vocab, input_length, output_length):
    # Encoder
    encoder_inputs = Input(shape=(input_length,))
    encoder_embedding = Embedding(input_vocab, 50)(encoder_inputs)
    encoder = LSTM(100, return_state=True)
    encoder_outputs, state_h, state_c = encoder(encoder_embedding)
    encoder_states = [state_h, state_c]

    # Decoder
    decoder_inputs = Input(shape=(output_length,))
    decoder_embedding = Embedding(output_vocab, 50)(decoder_inputs)
    decoder_lstm = LSTM(100, return_sequences=True)
    decoder_outputs = decoder_lstm(decoder_embedding, initial_state=encoder_states)
    decoder_dense = Dense(output_vocab, activation='softmax')
    decoder_outputs = decoder_dense(decoder_outputs)

    # Create model
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    return model

# (c) Prepare Data for Training
decoder_input_data = fra_data[:, :-1]  # Remove last token
decoder_target_data = fra_data[:, 1:]  # Remove first token

# Print shapes for debugging
print("\nTraining data shapes:")
print(f"Decoder input shape: {decoder_input_data.shape}")
print(f"Decoder target shape: {decoder_target_data.shape}")

# (d) Train the Model
model = build_model(
    eng_vocab_size,
    fra_vocab_size,
    max_eng_len,
    max_fra_len - 1
)

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    [eng_data, decoder_input_data],
    decoder_target_data,
    batch_size=2,
    epochs=100,
    validation_split=0.2
)

# (e) Inference Setup
class Translator:
    def _init_(self, model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len):
        self.model = model
        self.eng_tokenizer = eng_tokenizer
        self.fra_tokenizer = fra_tokenizer
        self.max_eng_len = max_eng_len
        self.max_fra_len = max_fra_len
        self.fra_index_word = {v: k for k, v in fra_tokenizer.word_index.items()}

    def translate(self, text):
        # Tokenize input text
        sequence = self.eng_tokenizer.texts_to_sequences([text])
        padded = pad_sequences(sequence, maxlen=self.max_eng_len, padding='post')

        # Initialize target sequence
        target_seq = np.zeros((1, self.max_fra_len - 1))

        # Generate translation
        prediction = self.model.predict([padded, target_seq])

        # Convert prediction to text
        output_sequence = np.argmax(prediction[0], axis=1)
        translated_text = []

        for idx in output_sequence:
            if idx != 0:
                word = self.fra_index_word.get(idx, '')
                if word and word not in ['<start>', '<end>']:
                    translated_text.append(word)

        return ' '.join(translated_text)

# (f) Translate New Sentences
translator = Translator(model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len)

# Test translations
test_sentences = [
    "hello",
    "thank you",
    "your name",
    "how are you"
]

print("\nTranslations:")
for sentence in test_sentences:
    translation = translator.translate(sentence)
    print(f"English: {sentence}")
    print(f"French: {translation}\n")
# Out:
# Input shapes:
# English data shape: (7, 4)
# French data shape: (7, 5)
#
# Training data shapes:
# Decoder input shape: (7, 4)
# Decoder target shape: (7, 4)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 546ms/step - accuracy: 0.0969 - loss: 2.7734 - val_accuracy: 0.6250 - val_loss: 2.7596
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3625 - loss: 2.7565 - val_accuracy: 0.5000 - val_loss: 2.7502
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2500 - loss: 2.7427 - val_accuracy: 0.2500 - val_loss: 2.7391
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.2500 - loss: 2.7247 - val_accuracy: 0.2500 - val_loss: 2.7207
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.2500 - loss: 2.7000 - val_accuracy: 0.2500 - val_loss: 2.6980
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.2500 - loss: 2.6738 - val_accuracy: 0.2500 - val_loss: 2.6691
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.2500 - loss: 2.6362 - val_accuracy: 0.2500 - val_loss: 2.6267
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.2500 - loss: 2.5831 - val_accuracy: 0.2500 - val_loss: 2.5624
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2500 - loss: 2.5067 - val_accuracy: 0.2500 - val_loss: 2.4675
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.2500 - loss: 2.4032 - val_accuracy: 0.2500 - val_loss: 2.3339
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.2500 - loss: 2.2659 - val_accuracy: 0.2500 - val_loss: 2.2168
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2500 - loss: 2.0908 - val_accuracy: 0.2500 - val_loss: 2.1863
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2500 - loss: 2.1002 - val_accuracy: 0.2500 - val_loss: 2.1294
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2500 - loss: 2.0002 - val_accuracy: 0.5000 - val_loss: 2.0266
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.3313 - loss: 2.0647 - val_accuracy: 0.6250 - val_loss: 1.9944
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3719 - loss: 1.9675 - val_accuracy: 0.5000 - val_loss: 1.9931
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3156 - loss: 1.9997 - val_accuracy: 0.5000 - val_loss: 2.0160
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3562 - loss: 1.9485 - val_accuracy: 0.5000 - val_loss: 2.0583
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4187 - loss: 1.7971 - val_accuracy: 0.5000 - val_loss: 2.1177
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4281 - loss: 1.6573 - val_accuracy: 0.3750 - val_loss: 2.1900
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4688 - loss: 1.6615 - val_accuracy: 0.3750 - val_loss: 2.2759
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 1.3818 - val_accuracy: 0.3750 - val_loss: 2.3502
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6125 - loss: 1.3502 - val_accuracy: 0.3750 - val_loss: 2.4246
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6062 - loss: 1.4602 - val_accuracy: 0.3750 - val_loss: 2.5093
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6687 - loss: 1.2294 - val_accuracy: 0.3750 - val_loss: 2.6157
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6062 - loss: 1.2460 - val_accuracy: 0.3750 - val_loss: 2.7344
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5906 - loss: 1.2265 - val_accuracy: 0.3750 - val_loss: 2.8752
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6844 - loss: 0.9851 - val_accuracy: 0.3750 - val_loss: 3.0348
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7344 - loss: 0.8523 - val_accuracy: 0.5000 - val_loss: 3.1781
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7656 - loss: 0.7151 - val_accuracy: 0.5000 - val_loss: 3.2912
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8375 - loss: 0.7341 - val_accuracy: 0.5000 - val_loss: 3.3756
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7844 - loss: 0.7391 - val_accuracy: 0.5000 - val_loss: 3.4682
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8875 - loss: 0.6234 - val_accuracy: 0.5000 - val_loss: 3.5812
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.5046 - val_accuracy: 0.5000 - val_loss: 3.6265
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.4994 - val_accuracy: 0.5000 - val_loss: 3.6721
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.3911 - val_accuracy: 0.5000 - val_loss: 3.7300
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9281 - loss: 0.3827 - val_accuracy: 0.5000 - val_loss: 3.7773
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.3338 - val_accuracy: 0.5000 - val_loss: 3.8355
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.3495 - val_accuracy: 0.5000 - val_loss: 3.8953
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2912 - val_accuracy: 0.5000 - val_loss: 3.9150
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.2562 - val_accuracy: 0.5000 - val_loss: 3.9493
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2715 - val_accuracy: 0.5000 - val_loss: 4.0010
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.2132 - val_accuracy: 0.5000 - val_loss: 4.0653
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.2109 - val_accuracy: 0.5000 - val_loss: 4.0922
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.2015 - val_accuracy: 0.5000 - val_loss: 4.0959
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1892 - val_accuracy: 0.5000 - val_loss: 4.1328
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.1776 - val_accuracy: 0.5000 - val_loss: 4.1853
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.1656 - val_accuracy: 0.5000 - val_loss: 4.1972
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.1759 - val_accuracy: 0.5000 - val_loss: 4.2039
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.1492 - val_accuracy: 0.5000 - val_loss: 4.2288
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.1172 - val_accuracy: 0.5000 - val_loss: 4.2636
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.1307 - val_accuracy: 0.5000 - val_loss: 4.3048
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.1239 - val_accuracy: 0.5000 - val_loss: 4.3223
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1089 - val_accuracy: 0.5000 - val_loss: 4.3119
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0987 - val_accuracy: 0.5000 - val_loss: 4.3173
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0918 - val_accuracy: 0.5000 - val_loss: 4.3898
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0911 - val_accuracy: 0.5000 - val_loss: 4.4243
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0903 - val_accuracy: 0.3750 - val_loss: 4.4215
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0776 - val_accuracy: 0.3750 - val_loss: 4.4093
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0710 - val_accuracy: 0.3750 - val_loss: 4.4058
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0703 - val_accuracy: 0.3750 - val_loss: 4.4227
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0679 - val_accuracy: 0.3750 - val_loss: 4.4485
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0679 - val_accuracy: 0.3750 - val_loss: 4.4735
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0687 - val_accuracy: 0.3750 - val_loss: 4.4893
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0632 - val_accuracy: 0.3750 - val_loss: 4.5038
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0600 - val_accuracy: 0.3750 - val_loss: 4.5163
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0540 - val_accuracy: 0.3750 - val_loss: 4.5307
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0522 - val_accuracy: 0.3750 - val_loss: 4.5435
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0519 - val_accuracy: 0.3750 - val_loss: 4.5549
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0517 - val_accuracy: 0.3750 - val_loss: 4.5631
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0454 - val_accuracy: 0.3750 - val_loss: 4.5705
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0426 - val_accuracy: 0.3750 - val_loss: 4.5789
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.3750 - val_loss: 4.5900
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0416 - val_accuracy: 0.3750 - val_loss: 4.6027
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0410 - val_accuracy: 0.3750 - val_loss: 4.6183
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0372 - val_accuracy: 0.3750 - val_loss: 4.6348
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0366 - val_accuracy: 0.3750 - val_loss: 4.6485
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0369 - val_accuracy: 0.3750 - val_loss: 4.6601
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0349 - val_accuracy: 0.3750 - val_loss: 4.6701
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0316 - val_accuracy: 0.3750 - val_loss: 4.6796
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0330 - val_accuracy: 0.3750 - val_loss: 4.6896
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0320 - val_accuracy: 0.3750 - val_loss: 4.6996
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 0.3750 - val_loss: 4.7095
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0274 - val_accuracy: 0.3750 - val_loss: 4.7199
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.3750 - val_loss: 4.7287
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.3750 - val_loss: 4.7377
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0251 - val_accuracy: 0.3750 - val_loss: 4.7477
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0251 - val_accuracy: 0.3750 - val_loss: 4.7569
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0264 - val_accuracy: 0.3750 - val_loss: 4.7656
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.3750 - val_loss: 4.7738
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.3750 - val_loss: 4.7808
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0241 - val_accuracy: 0.3750 - val_loss: 4.7878
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0235 - val_accuracy: 0.3750 - val_loss: 4.7946
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.3750 - val_loss: 4.8023
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.3750 - val_loss: 4.8099
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.3750 - val_loss: 4.8166
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.3750 - val_loss: 4.8233
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.3750 - val_loss: 4.8297
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.3750 - val_loss: 4.8371
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.3750 - val_loss: 4.8455
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-b4a0ddf59548> in <cell line: 146>()
#     144
#     145 # (f) Translate New Sentences
# --> 146 translator = Translator(model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len)
#     147
#     148 # Test translations
#
# TypeError: Translator() takes no arguments
